# %%
# Greeks for Greeks couse coding day 5
print(ord("P"))
print(int(float("3.14")))
# Out:
# 80
# 3

# %%
try:
  num=int("abc")
except ValueError as  e:
  print(f"Error:{e}")
# Out:
# Error:invalid literal for int() with base 10: 'abc'

# %%
numbers=[1,2,3,4,5]
avg=sum(numbers)/len(numbers)
print(avg)
# Out:
# 3.0

# %%
40
# Out:
# 40

# %% [markdown]
# # File  handling

# %%
fd=open('covid.txt','r')
txt=fd.read()
txt.replace('\n\n'," ")
txt.replace('\n',"")

fd.close()

# %%
print(txt)
# Out:
# From Wikipedia, the free encyclopedia
# For the pandemic caused by the said disease, see COVID-19 pandemic. For other diseases caused by coronaviruses, see Coronavirus diseases.
# Coronavirus disease 2019
# (COVID-19)
# Other names	COVID, (the) coronavirus
#
# Transmission and life-cycle of SARS-CoV-2, which causes COVID-19
# Pronunciation
# /kəˈroʊnəvaɪrəs/
# /ˌkoʊvɪdnaɪnˈtiːn, ˌkɒvɪd-/[1]
# Specialty	Infectious disease
# Symptoms	Fever, cough, fatigue, shortness of breath, vomiting, loss of taste or smell; some cases asymptomatic[2][3]
# Complications	Pneumonia, sepsis, ARDS, kidney failure, respiratory failure, pulmonary fibrosis, CKS, MIS-C, long COVID
# Usual onset	2–14 days (typically 5)
# after infection
# Duration	5 days to chronic
# Causes	SARS-CoV-2
# Diagnostic method	RT‑PCR testing, CT scan, rapid antigen test
# Prevention	Vaccination, face coverings, quarantine, social distancing, ventilation, hand washing
# Treatment	Symptomatic and supportive
# ...

# %%
txt
# Out:
# 'From Wikipedia, the free encyclopedia\nFor the pandemic caused by the said disease, see COVID-19 pandemic. For other diseases caused by coronaviruses, see Coronavirus diseases.\nCoronavirus disease 2019\n(COVID-19)\nOther names\tCOVID, (the) coronavirus\n\nTransmission and life-cycle of SARS-CoV-2, which causes COVID-19\nPronunciation\t\n/kəˈroʊnəvaɪrəs/\n/ˌkoʊvɪdnaɪnˈtiːn, ˌkɒvɪd-/[1]\nSpecialty\tInfectious disease\nSymptoms\tFever, cough, fatigue, shortness of breath, vomiting, loss of taste or smell; some cases asymptomatic[2][3]\nComplications\tPneumonia, sepsis, ARDS, kidney failure, respiratory failure, pulmonary fibrosis, CKS, MIS-C, long COVID\nUsual onset\t2–14 days (typically 5)\nafter infection\nDuration\t5 days to chronic\nCauses\tSARS-CoV-2\nDiagnostic method\tRT‑PCR testing, CT scan, rapid antigen test\nPrevention\tVaccination, face coverings, quarantine, social distancing, ventilation, hand washing\nTreatment\tSymptomatic and supportive\nFrequency\t774,367,797[4] conf
# ...
